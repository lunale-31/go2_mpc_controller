# %%
import pandas as pd, matplotlib
matplotlib.rcParams['figure.figsize'] = [20, 9]

# %%
df = pd.read_csv("../build/log.csv")
df

LEG = "BL"
hip = df[f"{LEG}_hip"]
hip.plot(legend=True)
thigh = df[f"{LEG}_thigh"]
thigh.plot(legend=True)
calf = df[f"{LEG}_calf"]
calf.plot(legend=True)


print(f"[{LEG}_hip] min: {hip.min()}, max: {hip.max()}")
print(f"[{LEG}_thigh] min: {thigh.min()}, max: {thigh.max()}")
print(f"[{LEG}_calf] min: {calf.min()}, max: {calf.max()}")
#JOINT = "THIGH"
#df.plot(x="time", y=[f"{LEG}_{JOINT}_dq", f"{LEG}_{JOINT}_dq_r"], legend=True)
#df.plot(x="time", y=[f"{LEG}_{JOINT}_kp", f"{LEG}_{JOINT}_kd"], legend=True)
# Out:
#       time  FR_HIP_mode  FR_HIP_kp  FR_HIP_kd  FR_HIP_q_r  FR_HIP_dq_r  \
# 0        1            0          0          0         0.0     0.000000
# 1        2            0          0          0         0.0     0.000000
# 2        3            0          0          0         0.0     0.000000
# 3        4            0          0          0         0.0     0.000000
# 4        5            0          0          0         0.0     0.000000
# ...    ...          ...        ...        ...         ...          ...
# 7713  7714            0          0          0        -0.2    -0.119252
# 7714  7715            0          0          0        -0.2    -0.119252
# 7715  7716            0          0          0        -0.2    -0.119252
# 7716  7717            0          0          0        -0.2    -0.119252
# 7717  7718            0          0          0        -0.2    -0.119252
#
#       FR_HIP_tau  FR_HIP_q  FR_HIP_dq  FR_THIGH_mode  ...  BL_THIGH_dq  \
# ...

# %%
df[f"{LEG}_y"][:4000].plot()
# Out:
# <AxesSubplot:>
