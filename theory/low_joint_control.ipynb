# %%
import pandas as pd, matplotlib
matplotlib.rcParams['figure.figsize'] = [20, 9]

# %% [markdown]
# ## Hip Joint

# %% [markdown]
# ### Square Wave Velocity Controller

# %%
df_square = pd.read_csv("../build/square_wave-hip.csv")[:1300]
df_square["dq"].plot(legend=True)
df_square["dq_r"].plot(legend=True)
df_square["signal"].plot(legend=True, alpha=0.2)
# Out:
# <AxesSubplot:>

# %%
df_square["q"].plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Sine Wave Velocity Setpoint

# %%
df_sine = pd.read_csv("../build/sine_wave-hip.csv")
df_sine["dq"].plot(legend=True)
df_sine["dq_r"].plot(legend=True)
df_sine["signal"].plot(legend=True, alpha=0.2)
# Out:
# <AxesSubplot:>

# %%
df_sine["q"].plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Sine Wave Position Setpoint (cascaded)

# %%
df_sine_pos = pd.read_csv("../build/cascaded_sine_wave-hip.csv")
df_sine_pos["dq"].plot(legend=True)
df_sine_pos["dq_r"].plot(legend=True)
df_sine_pos["signal"].plot(legend=True, alpha=0.2)
# Out:
# <AxesSubplot:>

# %%
df_sine_pos["q"].plot(legend=True)
df_sine_pos["q_r"].plot(legend=True)
#df_sine_pos["dq_r"].plot(legend=True, alpha=0.2)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Thigh Joint

# %% [markdown]
# ### Square Wave Velocity Controller

# %%
df_square = pd.read_csv("../build/square_wave-thigh.csv")
df_square["dq"].plot(legend=True)
df_square["dq_r"].plot(legend=True)
df_square["signal"].plot(legend=True, alpha=0.2)
# Out:
# <AxesSubplot:>

# %%
df_square["q"].plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Sine Wave Velocity Setpoint

# %%
df_sine = pd.read_csv("../build/sine_wave-thigh.csv")
df_sine["dq"].plot(legend=True)
df_sine["dq_r"].plot(legend=True)
df_sine["signal"].plot(legend=True, alpha=0.2)
# Out:
# <AxesSubplot:>

# %%
df_sine["q"].plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Sine Wave Position Setpoint (cascaded)

# %%
df_sine_pos = pd.read_csv("../build/cascaded_sine_wave-thigh.csv")
df_sine_pos["dq"].plot(legend=True)
df_sine_pos["dq_r"].plot(legend=True)
df_sine_pos["signal"].plot(legend=True, alpha=0.2)
# Out:
# <AxesSubplot:>

# %%
df_sine_pos["q"].plot(legend=True)
df_sine_pos["q_r"].plot(legend=True)
#df_sine_pos["dq_r"].plot(legend=True, alpha=0.2)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Calf Joint

# %% [markdown]
# ### Square Wave Velocity Controller

# %%
df_square = pd.read_csv("../build/square_wave-calf.csv")
df_square["dq"].plot(legend=True)
df_square["dq_r"].plot(legend=True)
df_square["signal"].plot(legend=True, alpha=0.2)
# Out:
# <AxesSubplot:>

# %%
df_square["q"].plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Sine Wave Velocity Setpoint

# %%
df_sine = pd.read_csv("../build/sine_wave-calf.csv")
df_sine["dq"].plot(legend=True)
df_sine["dq_r"].plot(legend=True)
df_sine["signal"].plot(legend=True, alpha=0.2)
# Out:
# <AxesSubplot:>

# %%
df_sine["q"].plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Sine Wave Position Setpoint (cascaded)

# %%
df_sine_pos = pd.read_csv("../build/cascaded_sine_wave-calf.csv")
df_sine_pos["dq"].plot(legend=True)
df_sine_pos["dq_r"].plot(legend=True)
df_sine_pos["signal"].plot(legend=True, alpha=0.2)
# Out:
# <AxesSubplot:>

# %%
df_sine_pos["q"].plot(legend=True)
df_sine_pos["q_r"].plot(legend=True)
#df_sine_pos["dq_r"].plot(legend=True, alpha=0.2)
# Out:
# <AxesSubplot:>
