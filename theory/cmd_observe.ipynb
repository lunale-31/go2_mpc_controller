# %%
import pandas as pd, matplotlib
matplotlib.rcParams['figure.figsize'] = [15, 9]

# %%
# %matplotlib widget
df = pd.read_csv("../data/sitting.csv")[2:]
#df = df[df["time"] > 3000][df["time"] < 4400]

for LEG in ["FL", "FR", "BL", "BR"]:
    print(f" === {LEG} ===")
    print("hip", df[f"{LEG}_HIP_q"].mean())
    print("thigh", df[f"{LEG}_THIGH_q"].mean())
    print("calf", df[f"{LEG}_CALF_q"].mean())

#df.plot(x="time", y=[f"{LEG}_HIP_q", f"{LEG}_HIP_dq", f"{LEG}_HIP_q_r", f"{LEG}_HIP_dq_r", f"{LEG}_HIP_tau"], legend=True)
#df.plot(x="time", y=[f"{LEG}_THIGH_q", f"{LEG}_THIGH_dq", f"{LEG}_THIGH_q_r", f"{LEG}_THIGH_dq_r", f"{LEG}_THIGH_tau"], legend=True)
#df.plot(x="time", y=[f"{LEG}_CALF_q", f"{LEG}_CALF_dq", f"{LEG}_CALF_q_r", f"{LEG}_CALF_dq_r", f"{LEG}_CALF_tau"], legend=True)

#JOINT = "THIGH"
#df.plot(x="time", y=[f"{LEG}_{JOINT}_dq", f"{LEG}_{JOINT}_dq_r"], legend=True)
#df.plot(x="time", y=[f"{LEG}_{JOINT}_kp", f"{LEG}_{JOINT}_kd"], legend=True)
# Out:
#  === FL ===
# hip -0.057996912747525116
# thigh 1.302564888613867
# calf -2.8047200618811776
#  === FR ===
# hip 0.107330540841584
# thigh 1.321973700495052
# calf -2.834827165841589
#  === BL ===
# hip 0.3161282995049492
# thigh 1.3089910148514845
# calf -2.8108784034653516
#  === BR ===
# hip -0.29676577599009807
# thigh 1.3163712995049537
# calf -2.8137438861386195
