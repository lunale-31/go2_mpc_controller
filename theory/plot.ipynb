# %%
import pandas as pd, matplotlib
matplotlib.rcParams['figure.figsize'] = [20, 9]
print("It works!")
# Out:
# It works!

# %% [markdown]
# ## Square Wave Controller

# %%
df_square = pd.read_csv("../build/square_wave.csv")
df_square["dq"].plot(legend=True)
df_square["dq_r"].plot(legend=True)
df_square["signal"].plot(legend=True, alpha=0.2)
# Out:
# <AxesSubplot:>

# %%
df_square["q"].plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Sine Wave Setpoint

# %%
df_sine = pd.read_csv("../build/sine_wave.csv")
df_sine["dq"].plot(legend=True)
df_sine["dq_r"].plot(legend=True)
df_sine["signal"].plot(legend=True, alpha=0.2)
# Out:
# <AxesSubplot:>

# %%
df_sine["q"].plot()
# Out:
# <AxesSubplot:>
